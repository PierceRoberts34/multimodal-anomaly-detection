# %%
from main import probabilitySignal, promptLLM
from IPython.display import Image

# %%
markovPath = probabilitySignal('markov_prob', 0.01)
Image(filename=markovPath)
# Out:
# Generating a single combined plot for the last 30 periods...

# %%
iforestPath = probabilitySignal('iforest_score', -0.15)
Image(filename=iforestPath)
# Out:
# Generating a single combined plot for the last 30 periods...

# %%
promptLLM(markovPath)
# Out:
# Feeding combined image to local llm...
#
# === LLM Analysis ===
# The graph for the date **2026-02-11** is significantly different in terms of its **number of anomalies (red points)** compared to other graphs. This graph exhibits a high concentration of anomalies in the morning and evening hours, making it distinct from the others in both the pattern and quantity of anomalies.
#
# - **Number of anomalies**: The graph has a significantly higher number of red points than most other graphs, indicating a strong deviation from the general trend of the dataset.
# - **Shape of the graph**: The blue line pattern of this graph is also very different, with a sharp drop in the early morning and a gradual increase toward the evening, contrasting with the smoother or more uniform patterns observed in other graphs.
#
# Thus, the graph on **2026-02-11** stands out as the one that is significantly different in both the **number of anomalies** and the **shape of the graph**.
# ====================
# Review complete in 30.18 seconds

# %%
promptLLM(iforestPath)
# Out:
# Feeding combined image to local llm...
#
# === LLM Analysis ===
# To determine which graph appears significantly different in terms of **shape** or **number of anomalies** (low probability points highlighted in red), we analyze the patterns across the charts:
#
# ---
#
# ### **Key Observations:**
# 1. **Anomalies (Red Dots)**: These represent low probability points. The number and distribution of these dots are critical indicators of "significantly different" behavior.
# 2. **Shape of the Blue Line (Forest Score)**: This reflects the overall trend of the data. A more "regular" or "variable" pattern may indicate a higher number of anomalies.
#
# ---
#
# ### **Analysis:**
# - Most charts show a **moderate number of red dots** (anomalies) scattered along the blue line.
# - However, **2026-02-24** stands out:
#   - **Number of Anomalies**: It has a **significantly higher number of red dots** compared to other charts.
#   - **Shape of the Blue Line**: The blue line appears **more irregular** and **less consistent**, which correlates with a higher concentration of anomalies.
#   - **Contextual Significance**: The red dots are clustered at the **start and end**, indicating a pattern of sudden spikes or drops, which is **less typical** for most charts and suggests a **higher level of deviation** from expected behavior.
#
# ---
#
# ### **Conclusion:**
# Among all the charts, **2026-02-24** is the one that appears **significantly different** due to:
# - A **higher number of red dots (anomalies)**.
# - A **less consistent blue line shape**, indicating a greater deviation from normal patterns.
#
# ---
#
# ### **Answer:**
# **2026-02-24**
# ====================
# Review complete in 28.02 seconds
